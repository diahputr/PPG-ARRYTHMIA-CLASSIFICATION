# %%
"""AF"""
# Out:
# 'AF'

# %%
#
import pandas as pd
import numpy as np
dfn1 = pd.read_csv('data_kosong/AF2.csv')
dfn1
# Out:
#                Time      II    PLETH
# 0      11:20:01.367    8.46  -168.00
# 1      11:20:01.367    8.46     7.76
# 2      11:20:01.367  -14.32   -76.00
# 3      11:20:01.367   -8.96   -75.00
# 4      11:20:01.367   -8.01   -74.00
# 5      11:20:01.367  -11.67   -74.00
# 6      11:20:01.367  -13.50   -74.00
# 7      11:20:01.367  -15.20   -73.00
# 8      11:20:01.367   11.75   -72.00
# 9      11:20:01.367   45.82   -71.00
# 10     11:20:01.367  -39.49   -72.00
# 11     11:20:01.367  -41.76   -71.00
# 12     11:20:01.367  -39.76   -70.00
# 13     11:20:01.367  163.00  1574.00
# 14     11:20:01.367  291.36  3796.00
# 15     11:20:01.414  267.72  4605.00
# 16     11:20:01.414  247.22  4738.00
# 17     11:20:01.414  224.18  4557.00
# 18     11:20:01.448  202.22  4245.00
# 19     11:20:01.448  182.64  3890.00
# 20     11:20:01.481  166.11  3535.00
# 21     11:20:01.515  149.83  3192.00
# 22     11:20:01.515  138.75  2876.00
# 23     11:20:01.548  133.12  2588.00
# 24     11:20:01.548  127.58  2326.00
# 25     11:20:01.596  115.23  2088.00
# 26     11:20:01.596   97.87  1874.00
# 27     11:20:01.633   87.41  1682.00
# 28     11:20:01.633   88.42  1507.00
# 29     11:20:01.681  141.31  1348.00
# ...             ...     ...      ...
# 18125  11:26:03.138   22.64   -85.00
# 18126  11:26:03.138   29.07   -86.00
# 18127  11:26:03.172   83.39   -86.00
# 18128  11:26:03.223  -17.03   -87.00
# 18129  11:26:03.223   -7.84   -85.00
# 18130  11:26:03.223    7.59   -86.00
# 18131   11:26:03.27   31.21   -85.00
# 18132   11:26:03.27   61.17   -86.00
# 18133  11:26:03.304   15.25   -86.00
# 18134  11:26:03.304   -8.57   -87.00
# 18135  11:26:03.338   -2.79   -92.00
# 18136  11:26:03.338  -41.30   -97.00
# 18137  11:26:03.373 -102.23  -104.00
# 18138  11:26:03.423 -122.99  -113.00
# 18139  11:26:03.423 -171.54  -122.00
# 18140  11:26:03.423 -164.29  -130.00
# 18141  11:26:03.462 -143.33  -140.00
# 18142  11:26:03.462 -128.48  -148.00
# 18143  11:26:03.507  -92.32  -155.00
# 18144  11:26:03.507  -12.54  -158.00
# 18145  11:26:03.556  -25.52  -160.00
# 18146  11:26:03.556  -28.60  -162.00
# 18147  11:26:03.556  -35.28  -162.00
# 18148  11:26:03.591  -63.13  -161.00
# 18149  11:26:03.625 -106.08  -157.00
# 18150  11:26:03.625 -119.37  -152.00
# 18151  11:26:03.667  -64.40  -142.00
# 18152  11:26:03.667   18.58  -136.00
# 18153  11:26:03.716   18.06  -129.00
# 18154  11:26:03.716   21.93  -123.00
#
# [18155 rows x 3 columns]

# %%
#check type data
print(type(dfn1['II'][0]))
print(type(dfn1['PLETH'][0]))
# Out:
# <class 'numpy.float64'>
# <class 'numpy.float64'>

# %%
#memotong data 
dfn1 = dfn1.loc[200:]
dfn1
# Out:
#                Time      II  PLETH
# 200    11:20:05.085    4.44 -134.0
# 201    11:20:05.085    3.94 -125.0
# 202    11:20:05.134    2.54 -120.0
# 203    11:20:05.134    0.60 -112.0
# 204    11:20:05.184   -1.25 -105.0
# 205    11:20:05.184   -3.20 -100.0
# 206    11:20:05.184   -4.87  -96.0
# 207    11:20:05.233   -6.28  -91.0
# 208    11:20:05.233   -7.16  -88.0
# 209    11:20:05.285   -7.41  -83.0
# 210    11:20:05.285   -7.31  -82.0
# 211    11:20:05.285   -6.85  -81.0
# 212    11:20:05.334   -6.68  -79.0
# 213    11:20:05.334   -6.56  -77.0
# 214    11:20:05.384   -6.63  -75.0
# 215    11:20:05.384   -6.54  -75.0
# 216    11:20:05.384   -6.08  -75.0
# 217    11:20:05.434   -5.16  -74.0
# 218    11:20:05.434   -2.79  -74.0
# 219    11:20:05.485   -1.94  -75.0
# 220    11:20:05.485   -3.91  -75.0
# 221    11:20:05.485   -5.23  -75.0
# 222    11:20:05.534   -6.72  -74.0
# 223    11:20:05.534   32.33  -74.0
# 224    11:20:05.585    7.81  -75.0
# 225    11:20:05.585  -26.48  -73.0
# 226    11:20:05.585  -26.90  -74.0
# 227    11:20:05.634  -25.57  -75.0
# 228    11:20:05.634  -24.24  -75.0
# 229    11:20:05.684  -23.15  -74.0
# ...             ...     ...    ...
# 18125  11:26:03.138   22.64  -85.0
# 18126  11:26:03.138   29.07  -86.0
# 18127  11:26:03.172   83.39  -86.0
# 18128  11:26:03.223  -17.03  -87.0
# 18129  11:26:03.223   -7.84  -85.0
# 18130  11:26:03.223    7.59  -86.0
# 18131   11:26:03.27   31.21  -85.0
# 18132   11:26:03.27   61.17  -86.0
# 18133  11:26:03.304   15.25  -86.0
# 18134  11:26:03.304   -8.57  -87.0
# 18135  11:26:03.338   -2.79  -92.0
# 18136  11:26:03.338  -41.30  -97.0
# 18137  11:26:03.373 -102.23 -104.0
# 18138  11:26:03.423 -122.99 -113.0
# 18139  11:26:03.423 -171.54 -122.0
# 18140  11:26:03.423 -164.29 -130.0
# 18141  11:26:03.462 -143.33 -140.0
# 18142  11:26:03.462 -128.48 -148.0
# 18143  11:26:03.507  -92.32 -155.0
# 18144  11:26:03.507  -12.54 -158.0
# 18145  11:26:03.556  -25.52 -160.0
# 18146  11:26:03.556  -28.60 -162.0
# 18147  11:26:03.556  -35.28 -162.0
# 18148  11:26:03.591  -63.13 -161.0
# 18149  11:26:03.625 -106.08 -157.0
# 18150  11:26:03.625 -119.37 -152.0
# 18151  11:26:03.667  -64.40 -142.0
# 18152  11:26:03.667   18.58 -136.0
# 18153  11:26:03.716   18.06 -129.0
# 18154  11:26:03.716   21.93 -123.0
#
# [17955 rows x 3 columns]

# %%
#pembersihan objek dr str yg tdk terpakai
dfn1['II'].replace('', np.nan, inplace=True)
dfn1.dropna(subset=['II'], inplace=True)
dfn1['PLETH'].replace('', np.nan, inplace=True)
dfn1.dropna(subset=['PLETH'], inplace=True)

dfn1.head(1)
# Out:
# C:\Users\Asus\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Asus\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#              Time    II  PLETH
# 200  11:20:05.085  4.44 -134.0

# %%
dfn = pd.concat([dfn1]).reset_index(drop=True)
len(dfn)
# Out:
# 17955

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 5))
plt.plot(dfn['PLETH'][:2000])

# %%
dfn = dfn.loc[0:1899]
dfn.to_csv('clean/af2clean.csv')

# %%
"""PVC"""
# Out:
# 'PVC'

# %%
dfv1 = pd.read_csv('data_kosong/PVC1.csv')
dfv1.head(1)
# Out:
#            Time    II  PLETH
# 0  00:01:58.112  0.36  0.516

# %%
print(type(dfv1['II'][0]))
print(type(dfv1['PLETH'][0]))
# Out:
# <class 'numpy.float64'>
# <class 'numpy.float64'>

# %%
dfv1['II'].replace('', np.nan, inplace=True)
dfv1.dropna(subset=['II'], inplace=True)
dfv1['PLETH'].replace('', np.nan, inplace=True)
dfv1.dropna(subset=['PLETH'], inplace=True)

dfv1.head(1)
# Out:
#            Time    II  PLETH
# 0  00:01:58.112  0.36  0.516

# %%
dfv = pd.concat([dfv1]).reset_index(drop=True)
len(dfv)
# Out:
# 951

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 5))
plt.plot(dfv['PLETH'][0:2000])

# %%
dfv = dfv.loc[0:1899]
dfv.to_csv('clean/PVC2.csv')

# %%
"Normal"
# Out:
# 'Normal'

# %%
import pandas as pd
import numpy as np
dfn1 = pd.read_csv('data_kosong/N1.csv')

# %%
#check type data
print(type(dfn1['II'][0]))
print(type(dfn1['Pleth'][0]))
# Out:
# <class 'numpy.float64'>
# <class 'numpy.int64'>

# %%
#memotong data 
dfn1 = dfn1.loc[100:]

# %%
#pembersihan objek dr str yg tdk terpakai
dfn1['II'].replace('', np.nan, inplace=True)
dfn1.dropna(subset=['II'], inplace=True)
dfn1['Pleth'].replace('', np.nan, inplace=True)
dfn1.dropna(subset=['Pleth'], inplace=True)

dfn1.head(1)
# Out:
#              Time  Pleth     II
# 100  20:56:13.146    -92  19.57

# %%
dfn = pd.concat([dfn1]).reset_index(drop=True)
len(dfn)
# Out:
# 5364

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 5))
plt.plot(dfn['Pleth'][:2000])

# %%
dfn = dfn.loc[0:1899]
dfn.to_csv('clean/N1.csv')

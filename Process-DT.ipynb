# %%
import pandas as pd
df = pd.read_csv('predictfitur/datareadyAFPVC.csv')
df.head(1)
# Out:
#           min         max        mean         med         std label
# 0 -452.777558 -135.314048 -325.448726 -349.759371  120.399877    AF

# %%
# df.drop(['Unnamed: 0'], axis=1, inplace=True)
df
# Out:
#              min         max        mean         med         std label
# 0    -452.777558 -135.314048 -325.448726 -349.759371  120.399877    AF
# 1    -386.798209  -64.985110 -292.581800 -350.780968  124.698731    AF
# 2    -319.839902 -114.712623 -170.357309 -147.056277   74.670062    AF
# 3    -466.520042 -100.164090 -308.042226 -371.601495  164.373852    AF
# 4    -514.093894  228.287258  -11.586602   92.345209  280.602157    AF
# 5    -471.081606   42.456504  -90.395700  -24.590898  191.531054    AF
# 6    -143.428674  142.854427   14.873681   41.170031  116.897685    AF
# 7    -590.532219  -89.574165 -401.257240 -460.218081  196.146594    AF
# 8    -357.807915  -68.276526 -200.692269 -203.256243   94.039086    AF
# 9    -584.484433 -100.262457 -390.413975 -454.210889  199.220857    AF
# 10   -230.190525  -77.337954 -115.860466  -97.463204   58.271604    AF
# 11   -162.302213   17.700993 -107.125821 -125.355656   64.167284     N
# 12   -596.085684  455.540927   83.440353  211.807790  394.459017     N
# 13   -289.465607  -30.007821 -191.724660 -206.735160   93.662134     N
# 14   -781.067508  428.153803   36.712277  214.751119  458.517926     N
# 15   -896.339293  -68.209062 -520.170669 -629.491132  359.592627     N
# 16   -737.652433  178.913206  -81.060450   47.908789  347.753362     N
# 17  -1043.188457  -86.997499 -603.739250 -734.002897  422.182734     N
# 18   -408.427246  339.366637   61.034249  152.125636  284.451255     N
# 19   -323.089799 -223.685243 -288.474176 -310.003711   40.414583    AF
# 20   -185.678513 -145.199068 -159.321401 -150.753970   16.433476    AF
# 21   -202.331305  -61.333342 -110.494238  -79.933317   57.321822    AF
# 22   -501.631269  107.901715 -104.512158   25.804382  247.616050    AF
# 23   -474.054204 -127.709950 -248.424497 -172.690546  140.876657    AF
# 24   -305.860587 -199.124824 -268.689699 -291.948068   43.410071    AF
# 25   -192.044326 -115.108073 -141.939106 -125.453808   31.256160    AF
# 26   -209.332492  -65.330090 -115.534518  -84.640139   58.509140    AF
# 27   -570.107048  172.903810  -86.016052   73.697811  301.940910     N
# 28   -409.014176 -196.675372 -270.700480 -223.870206   86.413196    AF
# 29   -252.100087 -204.043493 -235.367380 -245.928608   19.555508    AF
# ..           ...         ...         ...         ...         ...   ...
# 517     0.981444    3.050733    1.702752    1.255941    0.841073   PVC
# 518     0.981444    3.050733    1.702752    1.255941    0.841073   PVC
# 519     0.981444    3.050733    1.702752    1.255941    0.841073   PVC
# 520     0.981444    3.050733    1.702752    1.255941    0.841073   PVC
# 521     0.981444    3.050733    1.702752    1.255941    0.841073   PVC
# 522     1.328025    2.490848    1.733323    1.480992    0.472747   PVC
# 523     1.188596    2.066491    1.494687    1.306503    0.356697   PVC
# 524     1.009822    1.501744    1.181259    1.073793    0.200056     N
# 525    -0.980993   -0.434415   -0.624914   -0.506280    0.222226     N
# 526    -0.791342   -0.461987   -0.576898   -0.505856    0.133853     N
# 527    -0.450015   -0.445572   -0.447201   -0.446655    0.001854     N
# 528    -0.369184   -0.202592   -0.311156   -0.347873    0.067790     N
# 529    -0.174664   -0.084748   -0.143323   -0.162616    0.036544   PVC
# 530    -0.142376   -0.023928   -0.065195   -0.039674    0.048141   PVC
# 531    -0.341398    0.041808   -0.091814   -0.010087    0.155643   PVC
# 532    -0.540384    0.050811   -0.155172   -0.027313    0.240321   PVC
# 533    -0.865034    0.027997   -0.283313   -0.091176    0.362918     N
# 534    -1.023656   -0.109286   -0.427954   -0.230127    0.371690     N
# 535    -1.183929   -0.211739   -0.550629   -0.341021    0.395128     N
# 536    -0.781050   -0.233084   -0.424075   -0.305443    0.222765     N
# 537    -0.810069   -0.229979   -0.432156   -0.306977    0.235776     N
# 538    -0.845710   -0.223667   -0.440502   -0.306321    0.252820     N
# 539    -0.877109   -0.240772   -0.462612   -0.324895    0.258668     N
# 540    -0.953679   -0.271255   -0.509154   -0.362237    0.277323     N
# 541    -0.990918   -0.273935   -0.523888   -0.368732    0.291449     N
# 542    -1.051273   -0.274211   -0.545066   -0.377145    0.315863     N
# 543    -1.079697   -0.305946   -0.575685   -0.408298    0.314521     N
# 544    -1.093378   -0.351748   -0.610264   -0.450127    0.301439     N
# 545    -1.114840   -0.337952   -0.608771   -0.440864    0.315783     N
# 546    -1.111253   -0.357499   -0.620241   -0.457486    0.306368     N
#
# [547 rows x 6 columns]

# %%
x = df[['min','max','mean','med','std']]
y = df['label']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3,random_state=109)
# Out:
# C:\Users\Asus\Anaconda3\lib\site-packages\scipy\__init__.py:137: UserWarning: NumPy 1.16.5 or above is required for this version of SciPy (detected version 1.16.4)
#   UserWarning)

# %%
"""Desicion Tree"""
# Out:
# 'Desicion Tree'

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier() 
model.fit(X_train, y_train)

y_pred_d3 = model.predict(X_test)

from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, y_pred_d3))
# Out:
# Accuracy: 0.9696969696969697

# %%
from sklearn.metrics import confusion_matrix, plot_confusion_matrix, classification_report
cm = confusion_matrix(y_test, y_pred_d3)
cm
# Out:
# array([[116,   0,   0],
#        [  1,  31,   0],
#        [  0,   4,  13]], dtype=int64)

# %%
report = classification_report(y_test, y_pred_d3)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#           AF       0.99      1.00      1.00       116
#            N       0.89      0.97      0.93        32
#          PVC       1.00      0.76      0.87        17
#
#     accuracy                           0.97       165
#    macro avg       0.96      0.91      0.93       165
# weighted avg       0.97      0.97      0.97       165

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
cv = KFold(n_splits=5, random_state=3, shuffle=True)
scores = cross_val_score(model, x, y, cv=cv)
acc = (scores[0] + scores[1] + scores[2] + scores[3] + scores[4]) / 5
print(acc)
# Out:
# 0.9579149291075897

# %%
from sklearn.model_selection import cross_val_predict
yk_pred_d3 = cross_val_predict(model, x, y, cv=cv)

from sklearn.metrics import confusion_matrix
conf_mat = confusion_matrix(y, yk_pred_d3)
print(conf_mat)
# Out:
# [[381   5   0]
#  [  6 100   6]
#  [  0   7  42]]

# %%
from sklearn.metrics import confusion_matrix, plot_confusion_matrix, classification_report
report = classification_report(y, yk_pred_d3)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#           AF       0.98      0.99      0.99       386
#            N       0.89      0.89      0.89       112
#          PVC       0.88      0.86      0.87        49
#
#     accuracy                           0.96       547
#    macro avg       0.92      0.91      0.91       547
# weighted avg       0.96      0.96      0.96       547

# %%
clf = pd.read_csv('fitur/PVC2ready.csv')
clf.head(1)
# Out:
#    Unnamed: 0       min       max      mean       med       std  label
# 0           0 -0.462918 -0.044049 -0.190067 -0.099912  0.170224    NaN

# %%
clf.drop(['Unnamed: 0','label'], axis=1, inplace=True)
clf.head(1)
# Out:
#         min       max      mean       med       std
# 0 -0.462918 -0.044049 -0.190067 -0.099912  0.170224

# %%
x_clf = clf[['min','max','mean','med','std']]

# %%
y_clf = model.predict(x_clf)
hasil =pd.DataFrame(y_clf, columns = ['label'])
y_clf
# Out:
# array(['N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'PVC',
#        'PVC', 'PVC', 'PVC', 'PVC', 'N', 'N', 'N', 'N', 'N', 'N', 'PVC',
#        'PVC', 'PVC', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N',
#        'N', 'N', 'N', 'N', 'N', 'N', 'N', 'PVC', 'PVC', 'N', 'N', 'N',
#        'N', 'PVC', 'PVC', 'N', 'N', 'N', 'N', 'N', 'PVC', 'PVC', 'PVC',
#        'PVC', 'PVC', 'PVC', 'PVC', 'PVC', 'PVC', 'N', 'N', 'N', 'N', 'N',
#        'N', 'N', 'N', 'N', 'N', 'N', 'N', 'PVC'], dtype=object)

# %%
clf['label'] = hasil
clf.to_csv('predictfitur/PVC2.csv', index=False)
clf
# Out:
#          min       max      mean       med       std label
# 0  -0.462918 -0.044049 -0.190067 -0.099912  0.170224     N
# 1  -0.668918  0.006360 -0.229086 -0.082122  0.274569     N
# 2  -0.689019 -0.167926 -0.349571 -0.237176  0.211790     N
# 3  -0.776739 -0.153705 -0.370894 -0.235943  0.253272     N
# 4  -0.837489 -0.233875 -0.444303 -0.314403  0.245290     N
# 5  -0.931489 -0.201389 -0.455858 -0.298038  0.296771     N
# 6  -1.001446 -0.220032 -0.492424 -0.323953  0.317587     N
# 7  -1.023689 -0.284477 -0.542179 -0.382224  0.300484     N
# 8  -1.102636 -0.303588 -0.582124 -0.409757  0.324761     N
# 9  -1.043898 -0.380681 -0.611834 -0.468970  0.269540     N
# 10 -0.742347 -0.526234 -0.601550 -0.554273  0.087893     N
# 11 -0.485477  1.483548  0.200969 -0.221506  0.800070   PVC
# 12 -0.102453  2.055109  0.649507  0.181674  0.877137   PVC
# 13  0.326649  2.523778  1.092518  0.618614  0.893014   PVC
# 14  0.591765  2.700740  1.326868  0.870751  0.857273   PVC
# 15  0.815462  2.735405  1.484717  1.070332  0.780354   PVC
# 16  0.939563  2.617159  1.524385  1.162185  0.681861     N
# 17  0.962790  2.390911  1.460584  1.151682  0.580518     N
# 18  1.006769  2.084299  1.382429  1.150597  0.437889     N
# 19  0.984244  1.535715  1.176407  1.055534  0.224333     N
# 20  0.886074  1.090065  0.957390  0.913923  0.082845     N
# 21  0.622566  0.667505  0.651819  0.660620  0.018202     N
# 22  0.002715  0.123178  0.081109  0.106868  0.048950   PVC
# 23 -0.353169  0.202842  0.009106  0.129801  0.226057   PVC
# 24 -0.606237  0.047262 -0.180563 -0.040282  0.265536   PVC
# 25 -0.723575 -0.066349 -0.295361 -0.153378  0.267146     N
# 26 -0.845209 -0.139825 -0.385728 -0.233964  0.286650     N
# 27 -0.898708 -0.208094 -0.448787 -0.299625  0.280711     N
# 28 -0.996113 -0.226657 -0.494871 -0.328804  0.312748     N
# 29 -1.024287 -0.281220 -0.540268 -0.379453  0.302054     N
# ..       ...       ...       ...       ...       ...   ...
# 47  0.223358  0.462693  0.379414  0.431545  0.097332     N
# 48 -0.061611  0.122420  0.058158  0.097234  0.074739   PVC
# 49 -0.402013  0.159528 -0.036118  0.085561  0.228288   PVC
# 50 -0.688297  0.002130 -0.238568 -0.090314  0.280544     N
# 51 -0.774587 -0.116586 -0.345867 -0.203841  0.267450     N
# 52 -0.882794 -0.154924 -0.408655 -0.251846  0.295813     N
# 53 -0.852060 -0.274114 -0.475573 -0.350780  0.234909     N
# 54 -0.902707 -0.290408 -0.503842 -0.371631  0.248872     N
# 55 -0.736611  1.921898  0.190195 -0.380332  1.080245   PVC
# 56 -0.277993  2.855907  0.814169  0.134789  1.274051   PVC
# 57  0.813351  3.091817  1.607543  1.115184  0.926158   PVC
# 58  0.981444  3.050733  1.702752  1.255941  0.841073   PVC
# 59  0.981444  3.050733  1.702752  1.255941  0.841073   PVC
# 60  0.981444  3.050733  1.702752  1.255941  0.841073   PVC
# 61  0.981444  3.050733  1.702752  1.255941  0.841073   PVC
# 62  0.981444  3.050733  1.702752  1.255941  0.841073   PVC
# 63  1.328025  2.490848  1.733323  1.480992  0.472747   PVC
# 64  1.188596  2.066491  1.494687  1.306503  0.356697     N
# 65  1.009822  1.501744  1.181259  1.073793  0.200056     N
# 66 -1.284049 -0.413088 -0.716686 -0.528623  0.354006     N
# 67 -1.284049 -0.413088 -0.716686 -0.528623  0.354006     N
# 68 -1.337416 -0.408379 -0.732234 -0.531900  0.377580     N
# 69 -1.294585 -0.451479 -0.745401 -0.563266  0.342690     N
# 70 -1.337416 -0.408379 -0.732234 -0.531900  0.377580     N
# 71 -1.331716 -0.428423 -0.743291 -0.548248  0.367148     N
# 72 -1.331716 -0.428423 -0.743291 -0.548248  0.367148     N
# 73 -1.294585 -0.451479 -0.745401 -0.563266  0.342690     N
# 74 -1.073291 -0.552712 -0.734145 -0.620957  0.211673     N
# 75 -0.724812 -0.611814 -0.651345 -0.627394  0.045877     N
# 76 -0.252003 -0.021313 -0.171321 -0.219269  0.093578   PVC
#
# [77 rows x 6 columns]
